# %%
import pandas as pd
import numpy as np

# %% [markdown]
# data collection

# %%
dataset = pd.read_excel("/Users/saurabhingole/Downloads/bepec/pandas/6. Lending Data.xlsx")
# Out:
# /Users/saurabhingole/Documents/anaconda/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
dataset
# Out:
#                           Name of Lending Institution HQ State Rank TA Ratio1  \
# 0                                                 NaN      NaN   -1        -2
# 1                               American Express Co.       NY     1   0.23829
# 2                            First Citizens Banchares      NC     2  0.187393
# 3                            Wintrust Financial Corp.      IL     3  0.168999
# 4                                       Zions Bancorp      UT     4  0.117973
# ..                                                ...      ...  ...       ...
# 92                     Charles Schwab Bk                    NV   NR         -
# 93                     Third FS&LA                          OH   NR         -
# 94  *The bank was formerly known as GE Money Bank,...      NaN  NaN       NaN
# 95  1 TA = total domestic assets held by the lende...      NaN  NaN       NaN
# 96  Source: U.S. Small Business Administration, Of...      NaN  NaN       NaN
#
# ...

# %%
dataset.columns
# Out:
# Index(['Name of Lending Institution', 'HQ State', 'Rank', 'TA Ratio1',
#        'TBL Ratio1', 'Amount ($1,000)', 'Number ', 'Lender Asset Size',
#        'Amount ($1,000).1', 'Number .1', 'Unnamed: 10', 'Amount ($1,000).2',
#        'Number .2', 'CC Amount/TA1'],
#       dtype='object')

# %%
del dataset['Unnamed: 10']         #deleting the unnamed column

# %%
dataset
# Out:
#                           Name of Lending Institution HQ State Rank TA Ratio1  \
# 0                                                 NaN      NaN   -1        -2
# 1                               American Express Co.       NY     1   0.23829
# 2                            First Citizens Banchares      NC     2  0.187393
# 3                            Wintrust Financial Corp.      IL     3  0.168999
# 4                                       Zions Bancorp      UT     4  0.117973
# ..                                                ...      ...  ...       ...
# 92                     Charles Schwab Bk                    NV   NR         -
# 93                     Third FS&LA                          OH   NR         -
# 94  *The bank was formerly known as GE Money Bank,...      NaN  NaN       NaN
# 95  1 TA = total domestic assets held by the lende...      NaN  NaN       NaN
# 96  Source: U.S. Small Business Administration, Of...      NaN  NaN       NaN
#
# ...

# %%
dataset = dataset.dropna()  #dropping all the null values from the columns

# %%
dataset
# Out:
#           Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 1               American Express Co.       NY     1   0.23829   0.999544
# 2            First Citizens Banchares      NC     2  0.187393    0.49083
# 3            Wintrust Financial Corp.      IL     3  0.168999   0.383561
# 4                       Zions Bancorp      UT     4  0.117973   0.260577
# 5             Synovus Financial Corp.      GA     5  0.162333   0.381387
# ..                                ...      ...  ...       ...        ...
# 89  USAA Svg. Bank                          NV   NR         0          -
# 90                State Street Corp.       MA    NR         -          -
# 91     E Trade Bk                           VA   NR         -          -
# 92     Charles Schwab Bk                    NV   NR         -          -
# 93     Third FS&LA                          OH   NR         -          -
#
#    Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Name of Lending Institution    0
# HQ State                       0
# Rank                           0
# TA Ratio1                      0
# TBL Ratio1                     0
# Amount ($1,000)                0
# Number                         0
# Lender Asset Size              0
# Amount ($1,000).1              0
# Number .1                      0
# Amount ($1,000).2              0
# Number .2                      0
# CC Amount/TA1                  0
# dtype: int64

# %%
dataset = dataset.replace('-',np.nan)             #replacing '-' from columns to null values

# %%
dataset
# Out:
#           Name of Lending Institution HQ State Rank  TA Ratio1  TBL Ratio1  \
# 1               American Express Co.       NY     1   0.238290    0.999544
# 2            First Citizens Banchares      NC     2   0.187393    0.490830
# 3            Wintrust Financial Corp.      IL     3   0.168999    0.383561
# 4                       Zions Bancorp      UT     4   0.117973    0.260577
# 5             Synovus Financial Corp.      GA     5   0.162333    0.381387
# ..                                ...      ...  ...        ...         ...
# 89  USAA Svg. Bank                          NV   NR   0.000000         NaN
# 90                State Street Corp.       MA    NR        NaN         NaN
# 91     E Trade Bk                           VA   NR        NaN         NaN
# 92     Charles Schwab Bk                    NV   NR        NaN         NaN
# 93     Third FS&LA                          OH   NR        NaN         NaN
#
# ...

# %%
dataset = dataset.replace(np.nan,dataset.mean())          #replacing the null values with the column mean
# Out:
# /var/folders/3r/dntzkpvs20s26mlz3hyykz_h0000gn/T/ipykernel_50037/3290507860.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset = dataset.replace(np.nan,dataset.mean())

# %%
dataset
# Out:
#           Name of Lending Institution HQ State Rank  TA Ratio1  TBL Ratio1  \
# 1               American Express Co.       NY     1   0.238290    0.999544
# 2            First Citizens Banchares      NC     2   0.187393    0.490830
# 3            Wintrust Financial Corp.      IL     3   0.168999    0.383561
# 4                       Zions Bancorp      UT     4   0.117973    0.260577
# 5             Synovus Financial Corp.      GA     5   0.162333    0.381387
# ..                                ...      ...  ...        ...         ...
# 89  USAA Svg. Bank                          NV   NR   0.000000    0.251196
# 90                State Street Corp.       MA    NR   0.048668    0.251196
# 91     E Trade Bk                           VA   NR   0.048668    0.251196
# 92     Charles Schwab Bk                    NV   NR   0.048668    0.251196
# 93     Third FS&LA                          OH   NR   0.048668    0.251196
#
# ...

# %%
dataset['Lender Asset Size'].unique()
# Out:
# array(['>$50B               ', '$10B-$50B           ',
#        '>$10B               '], dtype=object)

# %%
dataset['Lender Asset Size']= dataset['Lender Asset Size'].replace(('>$50B               ', '$10B-$50B           ','>$10B               '),(0,1,2))

# %%
dataset
# Out:
#           Name of Lending Institution HQ State Rank  TA Ratio1  TBL Ratio1  \
# 1               American Express Co.       NY     1   0.238290    0.999544
# 2            First Citizens Banchares      NC     2   0.187393    0.490830
# 3            Wintrust Financial Corp.      IL     3   0.168999    0.383561
# 4                       Zions Bancorp      UT     4   0.117973    0.260577
# 5             Synovus Financial Corp.      GA     5   0.162333    0.381387
# ..                                ...      ...  ...        ...         ...
# 89  USAA Svg. Bank                          NV   NR   0.000000    0.251196
# 90                State Street Corp.       MA    NR   0.048668    0.251196
# 91     E Trade Bk                           VA   NR   0.048668    0.251196
# 92     Charles Schwab Bk                    NV   NR   0.048668    0.251196
# 93     Third FS&LA                          OH   NR   0.048668    0.251196
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 1 to 93
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Lending Institution  93 non-null     object
#  1   HQ State                     93 non-null     object
#  2   Rank                         93 non-null     object
#  3   TA Ratio1                    93 non-null     float64
#  4   TBL Ratio1                   93 non-null     float64
#  5   Amount ($1,000)              93 non-null     float64
#  6   Number                       93 non-null     float64
#  7   Lender Asset Size            93 non-null     int64
#  8   Amount ($1,000).1            93 non-null     float64
#  9   Number .1                    93 non-null     float64
#  10  Amount ($1,000).2            93 non-null     float64
#  11  Number .2                    93 non-null     float64
#  12  CC Amount/TA1                93 non-null     object
# ...

# %%
dataset = dataset.replace('NR',0)

# %%
dataset
# Out:
#           Name of Lending Institution HQ State  Rank  TA Ratio1  TBL Ratio1  \
# 1               American Express Co.       NY      1   0.238290    0.999544
# 2            First Citizens Banchares      NC      2   0.187393    0.490830
# 3            Wintrust Financial Corp.      IL      3   0.168999    0.383561
# 4                       Zions Bancorp      UT      4   0.117973    0.260577
# 5             Synovus Financial Corp.      GA      5   0.162333    0.381387
# ..                                ...      ...   ...        ...         ...
# 89  USAA Svg. Bank                          NV     0   0.000000    0.251196
# 90                State Street Corp.       MA      0   0.048668    0.251196
# 91     E Trade Bk                           VA     0   0.048668    0.251196
# 92     Charles Schwab Bk                    NV     0   0.048668    0.251196
# 93     Third FS&LA                          OH     0   0.048668    0.251196
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 1 to 93
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Lending Institution  93 non-null     object
#  1   HQ State                     93 non-null     object
#  2   Rank                         93 non-null     int64
#  3   TA Ratio1                    93 non-null     float64
#  4   TBL Ratio1                   93 non-null     float64
#  5   Amount ($1,000)              93 non-null     float64
#  6   Number                       93 non-null     float64
#  7   Lender Asset Size            93 non-null     int64
#  8   Amount ($1,000).1            93 non-null     float64
#  9   Number .1                    93 non-null     float64
#  10  Amount ($1,000).2            93 non-null     float64
#  11  Number .2                    93 non-null     float64
#  12  CC Amount/TA1                93 non-null     object
# ...

# %%
dataset['CC Amount/TA1'].unique()
# Out:
# array([0.28, '    .  ', 0, 0.01, 0.25, 0.05, 0.06, 0.1, 0.03, 0.07, 0.02],
#       dtype=object)

# %%
dataset = dataset.replace('    .  ',0)

# %%
dataset
# Out:
#           Name of Lending Institution HQ State  Rank  TA Ratio1  TBL Ratio1  \
# 1               American Express Co.       NY      1   0.238290    0.999544
# 2            First Citizens Banchares      NC      2   0.187393    0.490830
# 3            Wintrust Financial Corp.      IL      3   0.168999    0.383561
# 4                       Zions Bancorp      UT      4   0.117973    0.260577
# 5             Synovus Financial Corp.      GA      5   0.162333    0.381387
# ..                                ...      ...   ...        ...         ...
# 89  USAA Svg. Bank                          NV     0   0.000000    0.251196
# 90                State Street Corp.       MA      0   0.048668    0.251196
# 91     E Trade Bk                           VA     0   0.048668    0.251196
# 92     Charles Schwab Bk                    NV     0   0.048668    0.251196
# 93     Third FS&LA                          OH     0   0.048668    0.251196
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 1 to 93
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Lending Institution  93 non-null     object
#  1   HQ State                     93 non-null     object
#  2   Rank                         93 non-null     int64
#  3   TA Ratio1                    93 non-null     float64
#  4   TBL Ratio1                   93 non-null     float64
#  5   Amount ($1,000)              93 non-null     float64
#  6   Number                       93 non-null     float64
#  7   Lender Asset Size            93 non-null     int64
#  8   Amount ($1,000).1            93 non-null     float64
#  9   Number .1                    93 non-null     float64
#  10  Amount ($1,000).2            93 non-null     float64
#  11  Number .2                    93 non-null     float64
#  12  CC Amount/TA1                93 non-null     float64
# ...

# %%
dataset.to_csv('cleaned_data_assignment.csv')
